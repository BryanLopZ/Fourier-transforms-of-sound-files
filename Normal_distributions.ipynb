# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

# %%
# Plot between -10 and 10 with .001 steps.
def norm_dist(mean, sd):
    x_axis = np.arange(-3*sd+mean, 3*sd+mean, 0.01)

    # Calculating mean and standard deviation
    y = norm.pdf(x_axis, mean, sd)
    return y, x_axis

# %%
name = ["a", "e","i", "o", "u", "m"]
Sd = [430.5294,175.3963,73.3293,108.797,100.564,80.85109]
means = [541.0361,447.9764,276.9061,442.6011,323.0901,236.5687]

for i in range(len(Sd)):
    y, x_axis = norm_dist(means[i], Sd[i])
    plt.plot(x_axis,y, label = name[i])

plt.title("Distribución normal, primer armonico")
plt.xlim(0,4000)
plt.ylim(0,0.006)
plt.legend()
plt.show()

# %%
Sd_2 = [375.456,137.888,158.053,201.366,188.715,149.235]
means_2 = [558.624,308.033, 361.05,367.279,385.839,381.066]

for i in range(len(Sd)):
    y, x_axis = norm_dist(means_2[i], Sd_2[i])
    plt.plot(x_axis,y, label = name[i])

plt.title("Distribución normal, segundo armonico")
plt.xlim(0,4000)
plt.ylim(0,0.006)
plt.legend()
plt.show()

# %%
means_3 = [739.403,797.573,1281.84,646.697,600.928,735.351]
Sd_3 = [347.393,773.877,1110.2,264.501,217.905,498.466]

for i in range(len(Sd)):
    y, x_axis = norm_dist(means_3[i], Sd_3[i])
    plt.plot(x_axis,y, label = name[i])

plt.title("Distribución normal, tercer armonico")
plt.xlim(0,4000)
plt.ylim(0,0.006)
plt.legend()
plt.show()
